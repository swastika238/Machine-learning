# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df_index=pd.read_csv("D:\Machine Learning_\Day 000\data\economic_index.csv")
df_index
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_8868\1546328872.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df_index=pd.read_csv("D:\Machine Learning_\Day 000\data\economic_index.csv")
#     Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0            0  2017     12           2.75                5.3         1464
# 1            1  2017     11           2.50                5.3         1394
# 2            2  2017     10           2.50                5.3         1357
# 3            3  2017      9           2.50                5.3         1293
# 4            4  2017      8           2.50                5.4         1256
# 5            5  2017      7           2.50                5.6         1254
# 6            6  2017      6           2.50                5.5         1234
# 7            7  2017      5           2.25                5.5         1195
# ...

# %%
df_index.drop(columns=["Unnamed: 0", "year", "month"], errors="ignore", inplace=True)
df_index
# Out:
#     interest_rate  unemployment_rate  index_price
# 0            2.75                5.3         1464
# 1            2.50                5.3         1394
# 2            2.50                5.3         1357
# 3            2.50                5.3         1293
# 4            2.50                5.4         1256
# 5            2.50                5.6         1254
# 6            2.50                5.5         1234
# 7            2.25                5.5         1195
# 8            2.25                5.5         1159
# 9            2.25                5.6         1167
# 10           2.00                5.7         1130
# 11           2.00                5.9         1075
# 12           2.00                6.0         1047
# 13           1.75                5.9          965
# 14           1.75                5.8          943
# 15           1.75                6.1          958
# 16           1.75                6.2          971
# 17           1.75                6.1          949
# ...

# %%
df_index.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %%
df_index.isnull().sum()
# Out:
# interest_rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %%
import seaborn as sns
sns.pairplot(df_index)

# %%
df_index.corr()
# Out:
#                    interest_rate  unemployment_rate  index_price
# interest_rate           1.000000          -0.925814     0.935793
# unemployment_rate      -0.925814           1.000000    -0.922338
# index_price             0.935793          -0.922338     1.000000

# %%
# Visualize the datapoints more closelyplt.scatter(df_index['interst_rate'],df_index['unemployement_rate'],color='r')
print(df_index.columns)
# Out:
# Index(['interest_rate', 'unemployment_rate', 'index_price'], dtype='str')

# %%
plt.scatter(df_index['interest_rate'], df_index['unemployment_rate'], color='r')
plt.xlabel("interest rate")
plt.ylabel("unemployement rate")
# Out:
# Text(0, 0.5, 'unemployement rate')

# %%
# getting independent and dependent feaures
X=df_index.iloc[:,:-1]
y=df_index.iloc[:,-1]

# %%
# train and test
from sklearn.model_selection import train_test_split
X_test,X_train,y_test,y_train=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
import seaborn as sns

# %%
sns.regplot(x=df_index['interest_rate'], y=df_index['unemployment_rate'])
# Out:
# <Axes: xlabel='interest_rate', ylabel='unemployment_rate'>

# %% [markdown]
# from sklearn.preprocessing

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.36115756, -0.82078268],
#        [-1.08347268,  1.33377186],
#        [ 1.8057878 , -1.43636969],
#        [-1.08347268,  1.02597835],
#        [-0.36115756,  0.41039134],
#        [ 0.36115756, -0.51298918]])

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import cross_val_score
validation_train
